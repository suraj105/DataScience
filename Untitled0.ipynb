# %%
df=pd.read_csv('abc.csv')
df #before changing the base index
# Out:
#               Date    Price     Open  ...    Vol.  Change %    Close
# 0     Dec 09, 2021  47776.0  50477.6  ...  53.58K    -5.35%  50596.6
# 1     Dec 08, 2021  50473.9  50596.6  ...  55.59K    -0.24%  50547.4
# 2     Dec 07, 2021  50595.2  50547.4  ...  56.29K     0.07%  49412.1
# 3     Dec 06, 2021  50562.1  49412.1  ...  89.68K     2.34%  49196.4
# 4     Dec 05, 2021  49405.5  49196.4  ...  72.03K     0.43%  53620.7
# ...            ...      ...      ...  ...     ...       ...      ...
# 3260  Jan 05, 2013     13.4     13.5  ...  21.33K    -0.44%     13.4
# 3261  Jan 04, 2013     13.5     13.4  ...  29.64K     0.75%     13.3
# 3262  Jan 03, 2013     13.4     13.3  ...  18.03K     0.90%     13.3
# 3263  Jan 02, 2013     13.3     13.3  ...  17.97K     0.00%     13.5
# 3264  Jan 01, 2013     13.3     13.5  ...  28.41K    -1.55%     13.5
#
# [3265 rows x 8 columns]

# %%
df = df.set_index(pd.DatetimeIndex(df['Date'].values)) #setting index as date as we make change in order to the date
df #after chaging the base index
# Out:
#                     Date    Price     Open  ...    Vol.  Change %    Close
# 2021-12-09  Dec 09, 2021  47776.0  50477.6  ...  53.58K    -5.35%  50596.6
# 2021-12-08  Dec 08, 2021  50473.9  50596.6  ...  55.59K    -0.24%  50547.4
# 2021-12-07  Dec 07, 2021  50595.2  50547.4  ...  56.29K     0.07%  49412.1
# 2021-12-06  Dec 06, 2021  50562.1  49412.1  ...  89.68K     2.34%  49196.4
# 2021-12-05  Dec 05, 2021  49405.5  49196.4  ...  72.03K     0.43%  53620.7
# ...                  ...      ...      ...  ...     ...       ...      ...
# 2013-01-05  Jan 05, 2013     13.4     13.5  ...  21.33K    -0.44%     13.4
# 2013-01-04  Jan 04, 2013     13.5     13.4  ...  29.64K     0.75%     13.3
# 2013-01-03  Jan 03, 2013     13.4     13.3  ...  18.03K     0.90%     13.3
# 2013-01-02  Jan 02, 2013     13.3     13.3  ...  17.97K     0.00%     13.5
# 2013-01-01  Jan 01, 2013     13.3     13.5  ...  28.41K    -1.55%     13.5
#
# [3265 rows x 8 columns]

# %%
#calculating SMA, SD, UB and LB

#time period of 60, depends on how compact you want the interval to be 
#Simple moving average, Standard Deviation, Upper Band and Lower Band

period = 60

# According to the Bollinger Band , The following formulas are to be implemented
#Middle Band = n-period moving average
#Upper Band = Middle Band + ( y * n-period standard deviation)
#Lower Band = Middle Band - ( y * n-period standard deviation)
#Where:
#    n = number of periods
#    y = factor to apply to the standard deviation value, (typical default for y = 2)




#for SMA
df['SMA'] = df['Close'].rolling(window=period).mean()
#for SD
df['SD'] = df['Close'].rolling(window=period).std()
# Upper Bollinger Band
df['Upper'] = df['SMA'] + (df['SD'] * 2)
# lower Bollinger band
df['Lower'] = df['SMA'] - (df['SD'] * 2)

#create a list of Column with added Close , SD, Upper and Lower Data
column_list =['Close', 'SD', 'Upper','Lower']
#ploting the given data in chart
df[column_list].plot(figsize=(20,10)) #determining figure size

import matplotlib.pyplot as pot

pot.title('Bollinger Band Strategy for Bitcoin') #title for the Chart
pot.ylabel('USD Price in $') # labeling the y axis of the given Chart
pot.xlabel('Date in years') # labeling the x axis of the given Chart
pot.yticks(rotation = 15) #rotation of price by 15 degree 
pot.show() #Display the  Graph

# %%
#plot shade area between Bollinger bands

fig = pot.figure(figsize=(20,8))
#adding sub plot for gray area
gray = fig.add_subplot(111) # 
#get iindex values of data frame
x_axis = df.index
#plot and shade the area between UP and LB
gray.fill_between(x_axis, df['Upper'],df['Lower'],color ='grey')
#plot closing price and average
gray.plot(x_axis, df['Close'], color ='green', lw =2, label='Close Price')
gray.plot(x_axis, df['SMA'], color ='blue', lw =2, label='Simple moving average')
gray.set_title('Bollinger Band for Bitcoin')
gray.set_xlabel('Date in years')
gray.set_ylabel('USD Price in $')
pot.yticks(rotation = 15) #rotation of price by 15 degree 
gray.legend() #to sshow the legend
pot.show()  # to show the chart

# %%
#create new data

new_df = df[period-1:]
new_df
# Out:
#                     Date    Price  ...         Upper         Lower
# 2021-11-10  Nov 10, 2021  64932.6  ...  68669.917045  48211.909621
# 2021-11-09  Nov 09, 2021  66904.4  ...  68794.890454  48932.256213
# 2021-11-08  Nov 08, 2021  67527.9  ...  68687.982242  49768.257758
# 2021-11-07  Nov 07, 2021  63273.2  ...  68331.532792  50895.447208
# 2021-11-06  Nov 06, 2021  61483.9  ...  67817.869156  52223.450844
# ...                  ...      ...  ...           ...           ...
# 2013-01-05  Jan 05, 2013     13.4  ...     20.486156     11.347177
# 2013-01-04  Jan 04, 2013     13.5  ...     19.999719     11.353614
# 2013-01-03  Jan 03, 2013     13.4  ...     19.459813     11.420187
# 2013-01-02  Jan 02, 2013     13.3  ...     18.974745     11.491921
# 2013-01-01  Jan 01, 2013     13.3  ...     18.459132     11.607535
#
# [3236 rows x 12 columns]

# %%
def get_signal(data):

  buy_signal = []
  sell_signal = []

  for i in range(len(data['Close'])):
    if data['Close'][i] > data['Upper'][i]: # then you should sell
      buy_signal.append(np.nan)
      sell_signal.append(data['Close'][i])
    elif data['Close'][i] < data['Lower'][i]: # then buy
      buy_signal.append(data['Close'][i])
      sell_signal.append(np.nan)
    else:
        buy_signal.append(np.nan)
        sell_signal.append(np.nan)

  return(buy_signal, sell_signal)

# %%
import numpy as np

#Create two new columns
new_df['Buy'] = get_signal(new_df)[0]
new_df['Sell'] = get_signal(new_df)[1]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#plot all the data

fig = pot.figure(figsize=(30,15)) #size of graph
#add plot
gray = fig.add_subplot(1,1,1)
#get iindex values of data frame
x_axis = new_df.index
#plot and shade the area between UP and LB
gray.fill_between(x_axis, new_df['Upper'],new_df['Lower'],color ='grey')
#plot closing price and average
gray.plot(x_axis, new_df['Close'], color ='red', lw =3, label='Close Price', alpha= 0.1)
gray.plot(x_axis, new_df['SMA'], color ='blue', lw =3, label='Simple moving average', alpha= 0.1)
gray.scatter(x_axis, new_df['Buy'], color ='green', lw=3 , label='Buy', marker='^', alpha= 1) #adding the green buy arrow , when the algorith tell us to buy
gray.scatter(x_axis, new_df['Sell'], color ='red', lw=3 , label='Sell', marker='v', alpha= 1) #adding the red sell arrow , when the algorith tell us to sell

gray.set_title('Bollinger Band for Bitcoin')
gray.set_xlabel('Date')
gray.set_ylabel('USD Price in $')
pot.yticks(rotation = 15) #rotation of price by 15 degree 
gray.legend()  #showing the legend
pot.show() #displaying the graph

# %%
buy = []
sell = []
open_pos = False

for i in range(len(df)):
  if df.Lower[i] > df.Close[i]:
    if open_pos == False:
      buy.append(i)
      open_pos = True
  elif df.Upper[i] < df.Close[i]:
    if open_pos:
      sell.append(i)
      open_pos = False

# %%
total = pd.concat([df.iloc[buy].Close, df.iloc[sell].Close], axis = 1)

# %%
total.columns = ['Buys', 'Sells']

# %%
total
# Out:
#                Buys    Sells
# 2013-04-12      NaN    165.0
# 2013-04-18     68.4      NaN
# 2013-05-02      NaN    139.2
# 2013-05-05     98.1      NaN
# 2013-06-07      NaN    121.9
# ...             ...      ...
# 2021-03-27  51317.4      NaN
# 2021-06-19      NaN  38045.5
# 2021-08-08  42784.7      NaN
# 2021-09-08      NaN  52674.2
# 2021-10-16  57348.2      NaN
#
# [66 rows x 2 columns]

# %%
totalprofit = total.shift(-1).Sells - total.Buys

# %%
totalprofit
# Out:
# 2013-04-12        NaN
# 2013-04-18       70.8
# 2013-05-02        NaN
# 2013-05-05       23.8
# 2013-06-07        NaN
#                ...
# 2021-03-27   -13271.9
# 2021-06-19        NaN
# 2021-08-08     9889.5
# 2021-09-08        NaN
# 2021-10-16        NaN
# Length: 66, dtype: float64

# %%
relprofit = (total.shift(-1).Sells - total.Buys)/total.Buys

# %%
relprofit
# Out:
# 2013-04-12         NaN
# 2013-04-18    1.035088
# 2013-05-02         NaN
# 2013-05-05    0.242610
# 2013-06-07         NaN
#                 ...
# 2021-03-27   -0.258624
# 2021-06-19         NaN
# 2021-08-08    0.231146
# 2021-09-08         NaN
# 2021-10-16         NaN
# Length: 66, dtype: float64

# %%
relprofit.mean()
# Out:
# 0.3134015062735003

# %%
profitPercentagemean = relprofit.mean() * 100

# %%
profitPercentagemean
# Out:
# 31.340150627350027
